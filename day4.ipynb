# %%
import math
print(math.exp(23-45/90*45))
# Out:
# 1.6487212707001282

# %%
import math as mm
print(mm.)
# Out:
#   File "<ipython-input-2-995f84aaa2b3>", line 2
#     print(mm.)
#              ^
# SyntaxError: invalid syntax

# %%
sqt=math.sqrt(25)
print(sqt)

# %%
# prompt: generate all math functions

import math

# Functions with example arguments
print("math.acos(0.5):", math.acos(0.5))  # Arc cosine of 0.5
print("math.acosh(1):", math.acosh(1))  # Inverse hyperbolic cosine of 1
print("math.asin(0.5):", math.asin(0.5))  # Arc sine of 0.5
print("math.asinh(1):", math.asinh(1))  # Inverse hyperbolic sine of 1
print("math.atan(1):", math.atan(1))  # Arc tangent of 1
print("math.atan2(1, 1):", math.atan2(1, 1))  # Arc tangent of y/x, here 1/1
print("math.atanh(0.5):", math.atanh(0.5))  # Inverse hyperbolic tangent of 0.5
print("math.ceil(1.5):", math.ceil(1.5))  # Ceiling of 1.5
print("math.comb(5, 2):", math.comb(5, 2))  # Number of combinations of 5 items taken 2 at a time
print("math.copysign(1, -1):", math.copysign(1, -1))  # Copy sign of -1 to 1
print("math.cos(0):", math.cos(0))  # Cosine of 0
print("math.cosh(0):", math.cosh(0))  # Hyperbolic cosine of 0
print("math.degrees(math.pi):", math.degrees(math.pi))  # Convert pi radians to degrees
print("math.dist([0, 0], [3, 4]):", math.dist([0, 0], [3, 4]))  # Distance between points (0,0) and (3,4)
print("math.e:", math.e)  # Euler's number
print("math.erf(1):", math.erf(1))  # Error function of 1
print("math.erfc(1):", math.erfc(1))  # Complementary error function of 1
print("math.exp(1):", math.exp(1))  # Exponential of 1
print("math.expm1(1):", math.expm1(1))  # Exponential of 1 minus 1
print("math.fabs(-1):", math.fabs(-1))  # Absolute value of -1
print("math.factorial(5):", math.factorial(5))  # Factorial of 5
print("math.floor(1.5):", math.floor(1.5))  # Floor of 1.5
print("math.fmod(5.5, 2):", math.fmod(5.5, 2))  # Modulus of 5.5 and 2
print("math.frexp(8):", math.frexp(8))  # Mantissa and exponent of 8
print("math.fsum([0.1, 0.1, 0.1]):", math.fsum([0.1, 0.1, 0.1]))  # Sum of [0.1, 0.1, 0.1] with precision
print("math.gamma(5):", math.gamma(5))  # Gamma function of 5
print("math.gcd(8, 12):", math.gcd(8, 12))  # Greatest common divisor of 8 and 12
print("math.hypot(3, 4):", math.hypot(3, 4))  # Hypotenuse of a right triangle with sides 3 and 4
print("math.inf:", math.inf)  # Infinity
print("math.isclose(1.0, 1.0001):", math.isclose(1.0, 1.0001))  # Check if 1.0 is close to 1.0001
print("math.isfinite(1.0):", math.isfinite(1.0))  # Check if 1.0 is finite
print("math.isinf(math.inf):", math.isinf(math.inf))  # Check if inf is infinite
print("math.isnan(math.nan):", math.isnan(math.nan))  # Check if nan is NaN
print("math.isqrt(10):", math.isqrt(10))  # Integer square root of 10
print("math.lcm(8, 12):", math.lcm(8, 12))  # Least common multiple of 8 and 12
print("math.ldexp(0.625, 3):", math.ldexp(0.625, 3))  # 0.625 * (2 ** 3)
print("math.lgamma(5):", math.lgamma(5))  # Log gamma function of 5
print("math.log(10):", math.log(10))  # Natural logarithm of 10
print("math.log10(100):", math.log10(100))  # Base-10 logarithm of 100
print("math.log1p(0.1):", math.log1p(0.1))  # Natural logarithm of 1 + 0.1
print("math.log2(8):", math.log2(8))  # Base-2 logarithm of 8
print("math.modf(3.5):", math.modf(3.5))  # Fractional and integer parts of 3.5
print("math.nan:", math.nan)  # Not a number
print("math.nextafter(1.0, 2.0):", math.nextafter(1.0, 2.0))  # Next float after 1.0 towards 2.0
print("math.perm(5, 2):", math.perm(5, 2))  # Permutations of 5 items taken 2 at a time
print("math.pi:", math.pi)  # Pi constant
print("math.pow(2, 3):", math.pow(2, 3))  # 2 raised to the power of 3
print("math.prod([1, 2, 3, 4]):", math.prod([1, 2, 3, 4]))  # Product of [1, 2, 3, 4]
print("math.radians(180):", math.radians(180))  # Convert 180 degrees to radians
print("math.remainder(10, 3):", math.remainder(10, 3))  # Remainder of 10 divided by 3
print("math.sin(math.pi/2):", math.sin(math.pi/2))  # Sine of pi/2
print("math.sinh(0):", math.sinh(0))  # Hyperbolic sine of 0
print("math.sqrt(8):", math.sqrt(8))  # Square root of 8
print("math.tan(math.pi/4):", math.tan(math.pi/4))  # Tangent of pi/4
print("math.tanh(0):", math.tanh(0))  # Hyperbolic tangent of 0
print("math.tau:", math.tau)  # Tau constant (2 * pi)
print("math.trunc(1.5):", math.trunc(1.5))  # Truncate 1.5 to an integer
print("math.ulp(1.0):", math.ulp(1.0))  # Unit in the last place of 1.0

# %% [markdown]
# *italicized text![image.png](data:image/png;base64,...)*

# %%
#data and time Module

import datetime

# Get current date and time
now = datetime.datetime.now()
print("Current date and time:", now)

# %%
year = now.strftime("%Y")
print(now.strftime("%B"))
print("year:", year)

month = now.strftime("%m")
print("month:", month)

day = now.strftime("%d")
print("day:", day)

time = now.strftime("%H:%M:%S")
print("time:", time)

date_time = now.strftime("%m/%d/%Y, %H:%M:%S")
print("date and time:",date_time)

# %%
# Format date and time
#The strftime() method returns a string representing date and time using date, time or datetime object.
formatted_date_time = now.strftime("%Y-%m-%d %H:%M:%S")
print("Formatted date and time:", formatted_date_time)

# %%
# Create a datetime object from a string
date_string = "2023-11-15 10:30:00"
date_object = datetime.datetime.strptime(date_string, "%Y-%m-%d %H:%M:%S")
print("Datetime object from string:", date_object)

# %%
import datetime # Import the datetime module

# Timedelta for calculations
time_difference = datetime.timedelta(days=3, hours=12) # Access timedelta from the datetime module
future_date = now + time_difference
print("Future date:", future_date)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-843b581a6e58> in <cell line: 5>()
#       3 # Timedelta for calculations
#       4 time_difference = datetime.timedelta(days=3, hours=12) # Access timedelta from the datetime module
# ----> 5 future_date = now + time_difference
#       6 print("Future date:", future_date)
#
# NameError: name 'now' is not defined

# %%
# date object of today's date
from datetime import date

today = date.today()

print("Current year:", today.year)
print("Current month:", today.month)
print("Current day:", today.day)

# %%
from datetime import date, time # Import the 'time' class from datetime
# time(hour = 0, minute = 0, second = 0)
a = time()
print(a)

# time(hour, minute and second)
b = time(11, 34, 56)
print(b)

# time(hour, minute and second)
c = time(hour = 11, minute = 34, second = 56)
print(c)

# time(hour, minute, second, microsecond)
d = time(11, 34, 56, 234566)
print(d)

# %%
from datetime import datetime
import pytz

local = datetime.now()
print("Local:", local.strftime("%m/%d/%Y, %H:%M:%S"))


tz_NY = pytz.timezone('Asia/Karachi') # Changed the timezone identifier
datetime_NY = datetime.now(tz_NY)
print("NY:", datetime_NY.strftime("%m/%d/%Y, %H:%M:%S"))

tz_London = pytz.timezone('Europe/London')
datetime_London = datetime.now(tz_London)
print("Karachi:", datetime_London.strftime("%m/%d/%Y, %H:%M:%S"))

# %%
# prompt: Basic pyhton OS module
import os

# 1. Get current working directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)

# %%
# 2. List files and directories in a directory
directory_contents = os.listdir()
print("Directory Contents:", directory_contents)

# %%
# 3. Create a new directory
new_directory = r"C:\Users\Lenovo\documents\pyhton\mynew111"
os.mkdir(new_directory)
print("Created directory:", new_directory)

# %%
# 4. Check if a file exists
file_path="C:\\Users\\Lenovo\\documents\\pyhton\\mynew111"
if os.path.exists(file_path):
  print("File exists:", file_path)
else:
  print("File does not exist:", file_path)

# %%
# 6. Delete a file
file_to_delete = "file_to_delete.txt"
os.remove(file_to_delete)
print("Deleted file:", file_to_delete)

# %%
# 7. Delete a directory (if empty)
empty_directory = "empty_directory"
if os.path.exists(empty_directory):  # Check if the directory exists before attempting to delete
    os.rmdir(empty_directory)
    print("Deleted directory:", empty_directory)
else:
    print("Directory does not exist:", empty_directory)

# %%
# 8. Get file size
file_size = os.path.getsize("C:\\Users\\Lenovo\\documents\\pyhton\\mynew111")
print("File size:", file_size, "bytes")

# %%
# 9. Get file modification time
modification_time = os.path.getmtime("C:\\Users\\Lenovo\\documents\\pyhton\\mynew111")
print("Modification time:", modification_time)
# 10. Split a file path into directory and filename
path = "C:\\Users\\Lenovo\\documents\\pyhton\\mynew111"
directory, filename = os.path.split(path)
print("Directory:", directory)
print("Filename:", filename)

# %%
# 11. Join paths
parent_dir = "/path/to"
child_dir = "my_directory"
joined_path = os.path.join(parent_dir, child_dir)
print("Joined path:", joined_path)

# %%
# 12. Check if a path is a directory
is_directory = os.path.isdir("/path/to/my_directory")
print("Is directory:", is_directory)

# 13. Check if a path is a file
is_file = os.path.isfile("/path/to/my_file.txt")
print("Is file:", is_file)

# %% [markdown]
# ### **Python Pickle — Python object serialization**

# %% [markdown]
# Python pickle module is used for serializing and de-serializing a Python object structure. Any object in Python can be pickled so that it can be saved on disk. What Pickle does is it “serializes” the object first before writing it to a file. Pickling is a way to convert a Python object (list, dictionary, etc.) into a character stream. The idea is that this character stream contains all the information necessary to reconstruct the object in another Python script. It provides a facility to convert any Python object to a byte stream. This Byte stream contains all essential information about the object so that it can be reconstructed, or “unpickled” and get back into its original form in any Python.

# %% [markdown]
# ### **Sys Module in Python**

# %% [markdown]
# In this example, sys.version is used which returns a string containing the version of Python Interpreter with some additional information. This shows how the sys module interacts with the interpreter. Let us dive into the article to get more information about the sys module.

# %% [markdown]
# ![Pickling-In-python-(1).png](data:image/png;base64,...)

# %% [markdown]
# Python Pickle Example
# Pickling without a File
# In this example, we will serialize the dictionary data and store it in a byte stream. Then this data is deserialized using pickle.loads() function back into the original Python object.

# %%
import pickle
Omkar = {'key' : 'Omkar', 'name' : 'Omkar Pathak',
'age' : 21, 'pay' : 40000}
Jagdish = {'key' : 'Jagdish', 'name' : 'Jagdish Pathak',
'age' : 50, 'pay' : 50000}
db = {}
db['Omkar'] = Omkar
db['Jagdish'] = Jagdish
b = pickle.dumps(db)
myEntry = pickle.loads(b)
print(myEntry)

# %%
import pickle

# initializing data to be stored in db
Omkar = {'key' : 'Omkar', 'name' : 'Omkar Pathak',
'age' : 21, 'pay' : 40000}
Jagdish = {'key' : 'Jagdish', 'name' : 'Jagdish Pathak',
'age' : 50, 'pay' : 50000}

# database
db = {}
db['Omkar'] = Omkar
db['Jagdish'] = Jagdish

# For storing
# type(b) gives <class 'bytes'>;
b = pickle.dumps(db)

# For loading
myEntry = pickle.loads(b)
print(myEntry)

# %%
import pickle

#fruits=["Orange","Kiwi","Banana","Mango","Apple"]
#my_file=open("fruits","wb")
#pickle.dump(fruits,my_file)
#my_file.close()

my_file=open("fruits","rb")
fruits=pickle.load(my_file)
print(fruits)

# %%
# Python3 program to illustrate store
# efficiently using pickle module
# Module translates an in-memory Python object
# into a serialized byte stream—a string of
# bytes that can be written to any file-like object.

import pickle

def storeData():
    # initializing data to be stored in db
    Omkar = {'key' : 'Omkar', 'name' : 'Omkar Pathak',
    'age' : 21, 'pay' : 40000}
    Jagdish = {'key' : 'Jagdish', 'name' : 'Jagdish Pathak',
    'age' : 50, 'pay' : 50000}

    # database
    db = {}
    db['Omkar'] = Omkar
    db['Jagdish'] = Jagdish

    # Its important to use binary mode
    dbfile = open('examplePickle', 'ab')

    # source, destination
    pickle.dump(db, dbfile)
    dbfile.close()

def loadData():
    # for reading also binary mode is important
    dbfile = open('examplePickle', 'rb')
    db = pickle.load(dbfile)
    for keys in db:
        print(keys, '=>', db[keys])
    dbfile.close()

if __name__ == '__main__':
    storeData()
    loadData()
